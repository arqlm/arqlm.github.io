# %% [markdown]
# # Capitulo 1. Estudio Exploratorio de Datos
#
# ---
#
# ## 1.0 Contenidos
#
# La geoestadística busca estudiar una o varias variables regionalizadas obtenidas mediante la toma de muestras. Antes de proceder con el uso de métodos geoestadísticos propiamente tal (proximo capitulo), conviene realizar un estudio **exploratorio de los datos** disponibles (EDA, por sus siglas en ingles, *exploratory data analysis*), el cual tiene tres objetivos:
#
# 1.   Analizar (mediante herramientas estadísticas simples) la cantidad, la calidad y la ubicación de los datos disponibles.
# 2.   Definir la(s) zona(s) de estudio. Una división del campo en varias sub-zonas puede ser relevante si uno observa cambios abruptos en la distribución espacial de valores, o si la geología del fenómeno lo indica.
# 3.   Anticipar dificultades o problemas que puedan surgir en la fase de estimación local (por ejemplo, presencia de valores atípicos que se destacan de aquellos de los datos vecinos).
#
# El siguiente notebook ejemplificará los conceptos y herramientas con el estudio de una base de datos real de un yacimiento de cobre chileno. Estos datos constan de 68.960 muestras en las cuales se ha medido cinco variables (a saber, las concentraciones de cobre, oro, plata, molibdeno, y cianuro de cobre).
#
# 1. **Despliegue de datos (mapas)**
# 2. **Distribución estadística de valores**
#  - Histograma
#  - Estadísticas elementales
#  - Desagrupamiento
#  - Diagrama de caja
#  - Histograma acumulado
#  - Gráfico de probabilidad
# 3. **Análisis multivariable**
#  - Gráfico cuantil contra cuantil
#  - Nube de dispersión o de correlación
#  - Matriz de correlación
#  - Análisis en componentes principales
# 4. **Comportamiento espacial**
#  - Nube direccional
#  - Nube de correlación diferida
#
# El siguiente flujo de trabajo puede extenderse a cualquier otro depósito. Se entregan anotaciones en los pasos necesarios para poder llevar a la prácitca esta extension.
#
# ---
#
# Instalar librerias necesarias (en modo silencioso *-q*):

# %%
# !wget -q https://raw.githubusercontent.com/arqlm/arqlm.github.io/master/_static/libraries.txt
# !pip install -q -r /content/libraries.txt
# !rm -r /content/sample_data/ ## Esta linea no es necesaria cuando no se trabaja en colab.google
# Out:
# rm: cannot remove '/content/sample_data/': No such file or directory

# %% [markdown]
# ---
# ## 1.1 Despliegue de datos
#
# El despliegue de los datos permite visualizar su ubicación en el espacio. Cuando se trabaja en el espacio tridimensional, el despliegue puede hacerse con proyecciones (plantas y secciones) o vistas en perspectiva. Los mapas de datos pueden incluir información sobre los valores medidos y así dar una idea preliminar de la distribución y continuidad espacial de la variable en estudio, por ejemplo, utilizando símbolos de forma o tamaño variable o escalas de colores/de grises (Figura 1).
#
# ### 1.1.1 Carga de archivos

# %%
import pandas as pd
import numpy as np
import plotly.express as px

# Cargar base de datos en pandas
DH = pd.read_csv('EvYacData.csv', sep=',', encoding='latin1')
DH
# Out:
#              Este        Norte  Elevación  au_ppm  ag_ppm  cu_pct  aucn_ppm  \
# 0      472186.686  6925804.447   4220.763  -99.00   -99.0 -99.000     -99.0
# 1      472187.202  6925805.493   4213.861    0.30     2.3   0.011     -99.0
# 2      472187.343  6925805.770   4211.986    0.47    16.2   0.032     -99.0
# 3      472187.493  6925806.060   4210.013    0.31     2.3   0.018     -99.0
# 4      472187.642  6925806.351   4208.040    0.29     2.1   0.010     -99.0
# ...           ...          ...        ...     ...     ...     ...       ...
# 77836  471293.198  6925823.101   3761.674    0.03     1.0   0.002     -99.0
# 77837  471293.540  6925824.040   3759.942    0.01     0.7   0.001     -99.0
# 77838  471293.882  6925824.980   3758.209    0.01     0.4   0.001     -99.0
# 77839  471294.224  6925825.920   3756.477    0.06     1.3   0.004     -99.0
# 77840  471294.607  6925826.972   3754.538    0.06     0.5   0.003     -99.0
#
#        cucn_ppm  Zmin     Alte    Lito
# ...

# %% [markdown]
# ### 1.1.2 Visualización de datos (DH)

# %%
continuous = 'cu_pct'
fig = px.scatter_3d(DH, x='Este', y='Norte', z='Elevación', color=continuous, color_continuous_scale=px.colors.sequential.Rainbow[1:], range_color=[0.0, DH[continuous].quantile(0.95)])
fig.update_traces(marker=dict(size=2.0)) # Esta opcion controla el tamaño de los datos

# otras opciones para controlar el color de los elementos de la figura
fig.update_layout(scene = dict(
                    xaxis = dict(
                         backgroundcolor="white",
                         gridcolor="gray",
                         showbackground=True,
                         zerolinecolor="white",),
                    yaxis = dict(
                        backgroundcolor="white",
                        gridcolor="gray",
                        showbackground=True,
                        zerolinecolor="white"),
                    zaxis = dict(
                        backgroundcolor="white",
                        gridcolor="gray",
                        showbackground=True,
                        zerolinecolor="white",),
                    ),
                    font_family="Times New Roman",
                    font_color="black",
                  )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# <p><center><b>Figura 1: Mapa de datos de leyes de cobre. La escala de grises se refiere a la concentración de cobre expresada en porcentaje.</b></center></p>
